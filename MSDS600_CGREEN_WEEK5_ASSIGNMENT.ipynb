# %% [markdown]
# # DS Automation Assignment - Chris Green

# %%
import pandas as pd

df = pd.read_csv('prepped_churn_data.csv', index_col='Customer')
df
# Out:
#           tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# Customer
# 0              1             0         1              1           29.85
# 1             34             1         2              2           56.95
# 2              2             1         1              2           53.85
# 3             45             0         2              3           42.30
# 4              2             1         1              1           70.70
# ...          ...           ...       ...            ...             ...
# 7038          24             1         2              2           84.80
# 7039          72             1         2              4          103.20
# 7040          11             0         1              1           29.60
# 7041           4             1         1              2           74.40
# 7042          66             1         3              3          105.65
#
#           TotalCharges  Churn  Tenure_Charges_ratio
# Customer
# 0                29.85      0              0.033501
# 1              1889.50      0              0.017994
# 2               108.15      1              0.018493
# 3              1840.75      0              0.024447
# 4               151.65      1              0.013188
# ...                ...    ...                   ...
# 7038           1990.50      0              0.012057
# 7039           7362.90      0              0.009779
# 7040            346.45      0              0.031751
# 7041            306.60      1              0.013046
# 7042           6844.50      0              0.009643
#
# [7043 rows x 8 columns]

# %%
df.drop('Tenure_Charges_ratio', inplace=True, axis=1)

# %%
conda install -c conda-forge pycaret -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
automl = setup(df, target='Churn')
# Out:
# <style  type="text/css" >
# </style><table id="T_629fedfa_c7c9_11eb_9f51_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row0_col1" class="data row0 col1" >3412</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row1_col1" class="data row1 col1" >Churn</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row4_col1" class="data row4 col1" >(7043, 7)</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row6_col1" class="data row6 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row7_col1" class="data row7 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row11_col1" class="data row11 col1" >(4930, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row12_col1" class="data row12 col1" >(2113, 11)</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_629fedfa_c7c9_11eb_9f51_acde48001122level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_629fedfa_c7c9_11eb_9f51_acde48001122row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>

# %%
automl[6]
# Out:
# False

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_6a5a0eb8_c7c9_11eb_9f51_acde48001122 th {
#           text-align: left;
#     }#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row1_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row1_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row1_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row1_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row1_col6,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row1_col7,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row2_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row2_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row2_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row2_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row2_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row2_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row2_col6,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row2_col7,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row3_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row3_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row3_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row3_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row3_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row3_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row3_col6,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row3_col7,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row4_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row4_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row4_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row4_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row4_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row4_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row4_col6,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row4_col7,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row5_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row5_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row5_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row5_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row5_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row5_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row5_col6,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row5_col7,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row6_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row6_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row6_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row6_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row6_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row6_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row6_col6,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row6_col7,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row7_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row7_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row7_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row7_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row7_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row7_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row7_col6,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row7_col7,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row8_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row8_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row8_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row8_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row8_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row8_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row8_col6,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row8_col7,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row9_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row9_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row9_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row9_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row9_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row9_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row9_col6,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row9_col7,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row10_col0,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row10_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row10_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row10_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row10_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row10_col5,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row10_col6,#T_6a5a0eb8_c7c9_11 ...
#             text-align:  left;
#             text-align:  left;
#         }#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col2,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col6,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col7,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row1_col1,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row1_col4,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row12_col3,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row12_col5{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row1_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row2_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row3_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row6_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row7_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row8_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row9_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row10_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row11_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row4_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row5_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row12_col8,#T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_6a5a0eb8_c7c9_11eb_9f51_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6a5a0eb8_c7c9_11eb_9f51_acde48001122level0_row0" class="row_heading level0 row0" >lr</th>
#                         <td id="T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col0" class="data row0 col0" >Logistic Regression</td>
#                         <td id="T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col1" class="data row0 col1" >0.7982</td>
#                         <td id="T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col2" class="data row0 col2" >0.8392</td>
#                         <td id="T_6a5a0eb8_c7c9_11eb_9f51_acde48001122row0_col3" class="d

# %%
best_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=3412, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
df.iloc[-2:-1].shape
# Out:
# (1, 7)

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
#           tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# Customer
# 7041           4             1         1              2            74.4
#
#           TotalCharges  Churn  Label  Score
# Customer
# 7041             306.6      1      1  0.504

# %%
save_model(best_model, 'CBC')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Churn',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strate...
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=3412,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False)]],
#           verbose=False),
#  'CBC.pkl')

# %%
new_data = df.iloc[-2:-1].copy()

# %%
loaded_CBC = load_model('CBC')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predict_model(loaded_CBC, new_data)
# Out:
#           tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# Customer
# 7041           4             1         1              2            74.4
#
#           TotalCharges  Churn  Label  Score
# Customer
# 7041             306.6      1      1  0.504

# %%
from IPython.display import Code

Code('predict_churn.py')
# Out:
# import pandas as pd
# from pycaret.classification import predict_model, load_model
#
# df = pd.read_csv('new_churn_data.csv')
#
# model = load_model('CBC')
#
# predictions = predict_model(model, df)
#
# print (predictions)

# %%
# %run predict_churn.py
# Out:
# Transformation Pipeline and Model Successfully Loaded
#    customerID  tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0  9305-CKSKC      22             1         0              2           97.40
# 1  1452-KNGVK       8             0         1              1           77.30
# 2  6723-OKKJM      28             1         0              0           28.25
# 3  7832-POPKP      62             1         0              2          101.70
# 4  6348-TACGU      10             0         0              1           51.15
#
#    TotalCharges  charge_per_tenure  Label   Score
# 0        811.70          36.895455      0  0.7928
# 1       1701.95         212.743750      1  0.8359
# 2        250.90           8.960714      0  0.9737
# 3       3106.56          50.105806      0  0.9524
# 4       3440.97         344.097000      1  0.5876

# %% [markdown]
# # Summary

# %% [markdown]
# This assignment presented a number of challenges. While working through the autoML packages was straight forward, saving the model for future use and crafting a viable Python code required a fair amount of trial and error. One challenge was generated by the randomness of the best_model function. Every time the code was run, it selected a new model which meant changing all the labels and .py files. In the end, I left the model names as written ('CBC') even thought the last run selected logistic regression as the best. I also cut out the pickle read and write seciton because I could not get the code to run without an error. This was redundant anyway and I was able to complete the assignment requirements without this code. In the end the model seemed to do better at predicting no churn instead of churn. The scores were higher. This is useful in itself, given that the company could reduce its marketing efforts for this with a high score for no churn.
